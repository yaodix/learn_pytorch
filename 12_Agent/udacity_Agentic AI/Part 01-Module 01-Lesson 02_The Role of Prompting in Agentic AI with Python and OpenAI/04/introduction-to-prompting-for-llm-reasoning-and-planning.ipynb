# %% [markdown]
# # Pre-Lesson Exercise: Organize Your Workspace Space Kick-Off
#
# Before we get started on our course, let's take some time to set up and tidy our workspace. As an agentic twist on the matter, we will guide a Large Language Model (LLM) through a series of prompt refinements to create a practical plan to organize your personal work area.
#
# ## Outline
#
# 1. Start with a generic prompt
# 2. Add a professional role
# 3. Introduce concrete constraints
# 4. Bonus: Apply what you've learned

# %%
# Import necessary libraries
# No changes needed in this cell
from openai import OpenAI
from IPython.display import Markdown, display
import os

# %%
# If using the Vocareum API endpoint
# TODO: Fill in the missing parts marked with **********

client = OpenAI(
    base_url="https://api.deepseek.com",
    # Uncomment one of the following
    # api_key="**********",  # <--- TODO: Fill in your Vocareum API key here
    api_key=os.environ.get(
        "DS_API_KEY"
    ),  # <-- Alternately, set as an environment variable
)

# If using OpenAI's API endpoint
# client = OpenAI()

# %%
# No changes needed in this cell
from enum import Enum


class DSAIModels(str, Enum):
    DS_V4_flash = "deepseek-v4-flash"
    DS_V4_pro = "deepseek-v4-pro"


MODEL = DSAIModels.DS_V4_flash


def get_completion(system_prompt, user_prompt, model=MODEL):
    """
    Function to get a completion from the OpenAI API.
    Args:
        system_prompt: The system prompt
        user_prompt: The user prompt
        model: The model to use (default is ds-v4-flash)
    Returns:
        The completion text
    """
    messages = [
        {"role": "user", "content": user_prompt},
    ]
    if system_prompt is not None:
        messages = [
            {"role": "system", "content": system_prompt},
            *messages,
        ]
    try:
        response = client.chat.completions.create(
            model=model,
            messages=messages,
            temperature=0.7,
        )
        return response.choices[0].message.content
    except Exception as e:
        return f"An error occurred: {e}"


def display_responses(*args):
    """Helper function to display responses as Markdown, horizontally."""
    markdown_string = "<table><tr>"
    # Headers
    for arg in args:
        markdown_string += f"<th>System Prompt:<br />{arg['system_prompt']}<br /><br />"
        markdown_string += f"User Prompt:<br />{arg['user_prompt']}</th>"
    markdown_string += "</tr>"
    # Rows
    markdown_string += "<tr>"
    for arg in args:
        markdown_string += f"<td>Response:<br />{arg['response']}</td>"
    markdown_string += "</tr></table>"
    display(Markdown(markdown_string))

# %% [markdown]
# ## 1. Generic Prompt
#
# First, let's see what the model produces with a basic prompt.

# %%
# No changes needed in this cell
plain_system_prompt = "你是一个乐于助人的助手。"  # A generic system prompt
user_prompt = "请给我一个简单的计划，用于清理并整理我的工作空间。"

print(f"Sending prompt to {MODEL} model...")
baseline_response = get_completion(plain_system_prompt, user_prompt)
print("Response received!\n")

display_responses(
    {
        "system_prompt": plain_system_prompt,
        "user_prompt": user_prompt,
        "response": baseline_response,
    }
)
# Out:
# Sending prompt to DSAIModels.DS_V4_flash model...
# Response received!
# <table><tr><th>System Prompt:<br />你是一个乐于助人的助手。<br /><br />User Prompt:<br />请给我一个简单的计划，用于清理并整理我的工作空间。</th></tr><tr><td>Response:<br />当然可以！这是一个简单实用的清理整理计划，分四步走，利用空闲时间就能完成。
#
# ---
#
# ### 第一步：清空（10分钟）
# - 把桌面、抽屉、柜子里的所有物品全部拿出来，放在地上或临时空桌上。
# - 同时准备三个大箱子或袋子，分别贴上：**保留**、**丢弃/回收**、**待定**。
#
# ### 第二步：分类（20分钟）
# - 逐件拿起物品，快速做决定：
#   - **保留**：经常使用或真正需要的物品。
#   - **丢弃/回收**：坏掉的、过期的、没用的包装、废纸等。
#   - **待定**：不确定是否需要的，先放一边，等最后再决定。
#
# ### 第三步：归位（15分钟）
# - 只把“保留”的物品放回工作空间，按“使用频率”来摆放：
#   - **每天用的**：放在手边（桌面、抽屉最上层）。
#   - **偶尔用的**：放在稍远或较低的抽屉、柜子里。
#   - **很少用的**：收纳到收纳盒、文件柜或更高/更远的位置。
# - 尽量让桌面只留电脑、水杯和当前正在做的事。
# - 用笔筒、收纳盘、文件架把零碎物品分开，同类物品放在一起。
#
# ### 第四步：保持（每周5分钟）
# - 每天下班或工作结束后，花2分钟把桌面归回原位。
# - 每周设定一个5分钟“快速检查”，清理桌面新产生的垃圾和杂物。
# - 每月重新评估“待定”箱，如果还是不确定，果断处理掉。
#
# ---
#
# 如果觉得物品太多，可先只处理桌面，再做抽屉，分多次完成。重点是先“清空”再“归位”，养成“物归原位”的习惯就能长期保持整洁。加油！</td></tr></table>

# %% [markdown]
# ## 2. Add a Professional Role
#
# Now, let's add a professional role to see how it affects the response.
#
# <div style="color: red">NOTE: We will use the same user prompt for these examples. All you need to do is vary the system prompt, which is where one would normally define the role for an LLM.</div>

# %%
# TODO: Write a system prompt starting with "You are..." replacing the ***********
role_system_prompt = "你是一名专业的整理专家和生产力教练。"

print("Sending prompt with professional role...")
role_response = get_completion(role_system_prompt, user_prompt)
print("Response received!\n")

# Show last two prompts and responses
display_responses(
    {
        "system_prompt": plain_system_prompt,
        "user_prompt": user_prompt,
        "response": baseline_response,
    },
    {
        "system_prompt": role_system_prompt,
        "user_prompt": user_prompt,
        "response": role_response,
    },
)
# Out:
# Sending prompt with professional role...
# Response received!
# <table><tr><th>System Prompt:<br />你是一个乐于助人的助手。<br /><br />User Prompt:<br />请给我一个简单的计划，用于清理并整理我的工作空间。</th><th>System Prompt:<br />你是一名专业的整理专家和生产力教练。<br /><br />User Prompt:<br />请给我一个简单的计划，用于清理并整理我的工作空间。</th></tr><tr><td>Response:<br />当然可以！这是一个简单实用的清理整理计划，分四步走，利用空闲时间就能完成。
#
# ---
#
# ### 第一步：清空（10分钟）
# - 把桌面、抽屉、柜子里的所有物品全部拿出来，放在地上或临时空桌上。
# - 同时准备三个大箱子或袋子，分别贴上：**保留**、**丢弃/回收**、**待定**。
#
# ### 第二步：分类（20分钟）
# - 逐件拿起物品，快速做决定：
#   - **保留**：经常使用或真正需要的物品。
#   - **丢弃/回收**：坏掉的、过期的、没用的包装、废纸等。
#   - **待定**：不确定是否需要的，先放一边，等最后再决定。
#
# ### 第三步：归位（15分钟）
# - 只把“保留”的物品放回工作空间，按“使用频率”来摆放：
#   - **每天用的**：放在手边（桌面、抽屉最上层）。
#   - **偶尔用的**：放在稍远或较低的抽屉、柜子里。
#   - **很少用的**：收纳到收纳盒、文件柜或更高/更远的位置。
# - 尽量让桌面只留电脑、水杯和当前正在做的事。
# - 用笔筒、收纳盘、文件架把零碎物品分开，同类物品放在一起。
#
# ### 第四步：保持（每周5分钟）
# - 每天下班或工作结束后，花2分钟把桌面归回原位。
# - 每周设定一个5分钟“快速检查”，清理桌面新产生的垃圾和杂物。
# - 每月重新评估“待定”箱，如果还是不确定，果断处理掉。
#
# ---
#
# 如果觉得物品太多，可先只处理桌面，再做抽屉，分多次完成。重点是先“清空”再“归位”，养成“物归原位”的习惯就能长期保持整洁。加油！</td><td>Response:<br />以下是一个简单实用的工作空间整理计划，大约需要 **15-30 分钟**，可随时开始：
#
# ---
#
# **第1步：清空台面**
# 把所有物品从桌面上拿下来，堆成一堆（或放进空箱子）。这样能看清全部“财产”。
#
# **第2步：快速分类**
# 将物品分成三类：
# - **保留**（经常用或真心喜欢）
# - **要处理**（垃圾、损坏、过期的）
# - **不确定**（暂时放置一旁）
#
# **第3步：断舍离**
# 立即把“要处理”的物品扔掉或放回它们真正该待的地方（比如厨房、衣柜）。不要犹豫。
#
# **第4步：归位原则**
# 只把“保留”类物品放回桌面，遵循：
# - 常用物品放最近处（如手机、本子）
# - 每周用一次以上的放抽屉第一层
# - 很少用的放远处的抽屉或架子
#
# **第5步：建立“家”**
# 给每类物品固定一个位置：一个笔筒、一个收纳盘、一个文件兜。宁可少放，不要堆叠。
#
# **第6步：维护习惯**
# 每天离开前花 **2分钟** 把桌面恢复原状，长期保持就靠这个微习惯。
#
# ---
#
# 记住：**保持桌面80%空白**，只留下当下需要的工具和让你开心的小物件。开始行动吧！</td></tr></table>

# %% [markdown]
# ## 3. Add Constraints
#
# Let's add specific constraints to see how the model prioritizes tasks. Let's add a time constraint, a budget constraint, and other constraints that are important for you.

# %%
# TODO: Write a constraints system prompt replacing the ***********
constraints_system_prompt = f"""{role_system_prompt} 计划必须能在一小时内完成，不得购买任何物品，只能使用家中现有的物品。"""

print("Sending prompt with constraints...")
constraints_response = get_completion(constraints_system_prompt, user_prompt)
print("Response received!\n")

# Show last two prompts and responses
display_responses(
    {
        "system_prompt": role_system_prompt,
        "user_prompt": user_prompt,
        "response": role_response,
    },
    {
        "system_prompt": constraints_system_prompt,
        "user_prompt": user_prompt,
        "response": constraints_response,
    },
)
# Out:
# Sending prompt with constraints...
# Response received!
# <table><tr><th>System Prompt:<br />你是一名专业的整理专家和生产力教练。<br /><br />User Prompt:<br />请给我一个简单的计划，用于清理并整理我的工作空间。</th><th>System Prompt:<br />你是一名专业的整理专家和生产力教练。 计划必须能在一小时内完成，不得购买任何物品，只能使用家中现有的物品。<br /><br />User Prompt:<br />请给我一个简单的计划，用于清理并整理我的工作空间。</th></tr><tr><td>Response:<br />以下是一个简单实用的工作空间整理计划，大约需要 **15-30 分钟**，可随时开始：
#
# ---
#
# **第1步：清空台面**
# 把所有物品从桌面上拿下来，堆成一堆（或放进空箱子）。这样能看清全部“财产”。
#
# **第2步：快速分类**
# 将物品分成三类：
# - **保留**（经常用或真心喜欢）
# - **要处理**（垃圾、损坏、过期的）
# - **不确定**（暂时放置一旁）
#
# **第3步：断舍离**
# 立即把“要处理”的物品扔掉或放回它们真正该待的地方（比如厨房、衣柜）。不要犹豫。
#
# **第4步：归位原则**
# 只把“保留”类物品放回桌面，遵循：
# - 常用物品放最近处（如手机、本子）
# - 每周用一次以上的放抽屉第一层
# - 很少用的放远处的抽屉或架子
#
# **第5步：建立“家”**
# 给每类物品固定一个位置：一个笔筒、一个收纳盘、一个文件兜。宁可少放，不要堆叠。
#
# **第6步：维护习惯**
# 每天离开前花 **2分钟** 把桌面恢复原状，长期保持就靠这个微习惯。
#
# ---
#
# 记住：**保持桌面80%空白**，只留下当下需要的工具和让你开心的小物件。开始行动吧！</td><td>Response:<br />好的，这里是一个**1小时内**、**零购物**、只用家中现有物品的极简整理计划。请按顺序执行，每完成一项打勾。
#
# ## 工具准备（2分钟）
# - 找1个空纸箱或收纳盒（装杂物）
# - 找1个垃圾袋（装真正要丢的东西）
# - 找1块抹布或湿纸巾（擦拭桌面）
#
# ## 第一步：清空桌面（5分钟）
# 把桌面上所有物品，全部放到地上或床上，暂时分类堆放：
# - 常用物（水杯、笔、鼠标垫）
# - 不常用物（旧文件、数据线、装饰品）
# - 垃圾（空包装、废纸、坏掉的笔）
#
# ## 第二步：快速决定去留（10分钟）
# 用**“15秒规则”**处理每一件不常用物品：
# - 真没用、坏了、过期了 → 扔进垃圾袋
# - 去年用过的、可能会再用的 → 放回抽屉/柜子
# - 不确定的 → 放进纸箱，写上“待定”，封好，放到角落，1个月后没打开再扔
#
# ## 第三步：擦拭清理（3分钟）
# 用抹布擦干净桌面、键盘、显示器边框，顺带把鼠标垫拍一拍。
#
# ## 第四步：按“使用频率”归位（15分钟）
# **高频物品留在桌面**（伸手可及）：
# - 手机、水杯、常用笔、便签本
# - 用一个家里现有的小托盘/碗装着笔和杂物
#
# **低频物品收进抽屉或柜子**：
# - 数据线用旧发圈/纸绳绑好，放进一个抽屉格
# - 文件、纸张叠整齐，放进文件夹或纸盒里
# - 不常用工具、备用文具统一放一个盒子
#
# **墙面或桌边**：用现有挂钩/夹子挂起耳机、包包或常用钥匙。
#
# ## 第五步：建立一个“每日清空点”（5分钟）
# 在桌面上找一个固定的小角落，放一个空的浅盘子/小盒子（家中现有）。
# 每天离开前，把不属于桌面的东西放进这个盒子。第二天早上，只取当天需要的物品。
#
# ## 第六步：最后收尾（5分钟）
# - 把垃圾袋拿出家门。
# - 把“待定”纸箱放好。
# - 给自己留一杯水，坐回桌前，感受一下清爽的环境。
#
# ---
#
# **核心原则：**
# - 桌面只留20%常用物品，其余全部藏起来。
# - 不买收纳盒，用鞋盒、纸袋、杯子代替。
# - 定时器设定为60分钟，完成后立刻停止，不追求完美，只求“明显变好”。
#
# 现在，计时开始。祝你整理顺利！</td></tr></table>

# %% [markdown]
# ### Observations
#
# Note how the model:
# - Prioritizes tasks within the given timeframe
# - Works within the budget
# - Handles other constraints

# %% [markdown]
# ## 4. Request Step-by-Step Reasoning
#
# Now, let's ask the model to explain its reasoning and provide a final checklist.

# %%
# TODO: Ask the LLM to explain its reasoning step by step, replacing the ***********
reasoning_system_prompt = (
    f"{constraints_system_prompt}请在给出最终检查清单之前，以清晰周到的方式解释计划每个步骤的理由。"
)

print("Sending prompt with reasoning request...")
reasoning_response = get_completion(reasoning_system_prompt, user_prompt)
print("Response received!\n")

# Display the last two prompts and responses
display_responses(
    {
        "system_prompt": constraints_system_prompt,
        "user_prompt": user_prompt,
        "response": constraints_response,
    },
    {
        "system_prompt": reasoning_system_prompt,
        "user_prompt": user_prompt,
        "response": reasoning_response,
    },
)
# Out:
# Sending prompt with reasoning request...
# Response received!
# <table><tr><th>System Prompt:<br />你是一名专业的整理专家和生产力教练。 计划必须能在一小时内完成，不得购买任何物品，只能使用家中现有的物品。<br /><br />User Prompt:<br />请给我一个简单的计划，用于清理并整理我的工作空间。</th><th>System Prompt:<br />你是一名专业的整理专家和生产力教练。 计划必须能在一小时内完成，不得购买任何物品，只能使用家中现有的物品。请在给出最终检查清单之前，以清晰周到的方式解释计划每个步骤的理由。<br /><br />User Prompt:<br />请给我一个简单的计划，用于清理并整理我的工作空间。</th></tr><tr><td>Response:<br />好的，这里是一个**1小时内**、**零购物**、只用家中现有物品的极简整理计划。请按顺序执行，每完成一项打勾。
#
# ## 工具准备（2分钟）
# - 找1个空纸箱或收纳盒（装杂物）
# - 找1个垃圾袋（装真正要丢的东西）
# - 找1块抹布或湿纸巾（擦拭桌面）
#
# ## 第一步：清空桌面（5分钟）
# 把桌面上所有物品，全部放到地上或床上，暂时分类堆放：
# - 常用物（水杯、笔、鼠标垫）
# - 不常用物（旧文件、数据线、装饰品）
# - 垃圾（空包装、废纸、坏掉的笔）
#
# ## 第二步：快速决定去留（10分钟）
# 用**“15秒规则”**处理每一件不常用物品：
# - 真没用、坏了、过期了 → 扔进垃圾袋
# - 去年用过的、可能会再用的 → 放回抽屉/柜子
# - 不确定的 → 放进纸箱，写上“待定”，封好，放到角落，1个月后没打开再扔
#
# ## 第三步：擦拭清理（3分钟）
# 用抹布擦干净桌面、键盘、显示器边框，顺带把鼠标垫拍一拍。
#
# ## 第四步：按“使用频率”归位（15分钟）
# **高频物品留在桌面**（伸手可及）：
# - 手机、水杯、常用笔、便签本
# - 用一个家里现有的小托盘/碗装着笔和杂物
#
# **低频物品收进抽屉或柜子**：
# - 数据线用旧发圈/纸绳绑好，放进一个抽屉格
# - 文件、纸张叠整齐，放进文件夹或纸盒里
# - 不常用工具、备用文具统一放一个盒子
#
# **墙面或桌边**：用现有挂钩/夹子挂起耳机、包包或常用钥匙。
#
# ## 第五步：建立一个“每日清空点”（5分钟）
# 在桌面上找一个固定的小角落，放一个空的浅盘子/小盒子（家中现有）。
# 每天离开前，把不属于桌面的东西放进这个盒子。第二天早上，只取当天需要的物品。
#
# ## 第六步：最后收尾（5分钟）
# - 把垃圾袋拿出家门。
# - 把“待定”纸箱放好。
# - 给自己留一杯水，坐回桌前，感受一下清爽的环境。
#
# ---
#
# **核心原则：**
# - 桌面只留20%常用物品，其余全部藏起来。
# - 不买收纳盒，用鞋盒、纸袋、杯子代替。
# - 定时器设定为60分钟，完成后立刻停止，不追求完美，只求“明显变好”。
#
# 现在，计时开始。祝你整理顺利！</td><td>Response:<br />好的，我为您制定了一个可以在60分钟内完成的整理计划。整个过程不需要购买任何收纳工具，只使用家中现有的物品。下面我先解释为什么按这个顺序做，每个步骤背后的逻辑，然后给您一份最终的检查清单。
#
# **第一步：清空工作区（约10分钟）**
# 把桌面上、抽屉里所有东西都拿出来，堆在一个临时区域（比如床或干净的地板）。
#
# *理由*：你不可能在混乱中整理混乱。清空能让你看到“全部家底”，避免在原有杂物上“打转”。同时，一张空桌子会给你心理上的清零感，让后续分类更高效。
#
# **第二步：快速分类（约10分钟）**
# 把所有物品分成三堆：
# - **要保留的**：这周内实际会用到的东西。
# - **要扔掉的**：垃圾、过期物品、没用的数据线等。
# - **要移走的**：不属于工作区的东西，比如餐具、杂志、不用的装饰品，放回它们该待的房间。
#
# *理由*：整理的本质是减少干扰。快速分成三堆，能避免你陷入“万一以后用得上”的纠结。你只需要保留使用频率高、与工作直接相关的物品，其他东西清出视线，这能立刻降低心理负担。
#
# **第三步：清洁表面和容器（约5分钟）**
# 用湿抹布或湿巾擦拭桌面、键盘、显示器边框，以及你准备用来收纳的盒子/托盘。
#
# *理由*：灰尘和污渍会让人莫名烦躁。一个干净的工作区会提高你的专注力，而且这个步骤成本极低，用家中的清洁用品即可完成。
#
# **第四步：用现有物品分组收纳（约20分钟）**
# 把你决定保留的物品，按类别归拢，并找家中的现有容器来“装”：
# - **文具类**（笔、剪刀、便利贴）→ 放在一个笔筒或杯子、罐头盒里。
# - **纸张和笔记本**→ 用文件夹、档案袋或硬纸盒（如鞋盒）竖立摆放。
# - **电子设备配件**→ 用橡皮筋、扎带或长尾夹把数据线捆好，放在抽屉或小盒子里。
# - **日常零碎**（耳机、U盘、计算器）→ 用分隔盒、纸袋或小托盘分类，避免混杂。
#
# *理由*：用现有物品不仅省钱，还能倒逼你因陋就简、减少物料。归类收纳遵循“一触即达”原则：最常用的物品（笔、本子、手机）放在手边，不常用的（多余的硬盘、旧文档）放进抽屉或书架上层。这样工作起来无需起身寻觅。
#
# **第五步：布置最终格局并立下“公共规则”（约5分钟）**
# 把所有收纳好的物品放回桌面，注意“水平面只留常驻物品”——也就是每天都要用的东西。然后明确：
# - 桌面中央留出至少一半空位，用来写字或放笔记本电脑。
# - 其他物品各安其位，每次都放回原位。
# - 设定每天下班前用5分钟快速整理桌面，让第二天开始工作时清爽如初。
#
# *理由*：如果最后的“定位”不固定，很快就会重新混乱。一个显眼的空位会提醒你保持简洁，而每日5分钟收尾的习惯，是防止反弹的保险丝。
#
# ---
#
# **最终检查清单**
#
# - [ ] 桌面表面被清空，并用抹布擦拭干净
# - [ ] 所有物品已经分为“保留/丢弃/移走”三类，垃圾已扔，非工作物品已移出
# - [ ] 桌面上的保留物品已用家中现有容器（杯子、盒子、托盘、扎带等）分组收纳
# - [ ] 最常用的3～5件物品（如笔、本子、手机）位于手边
# - [ ] 数据线已捆好，不散落在桌面
# - [ ] 桌面中央留有至少一半空白工作区
# - [ ] 已给自己定下每日5分钟收尾规则
# - [ ] 整体完成时间不超过60分钟，且没有买任何新东西
#
# 这个计划简单直接，但非常有效。现在，您可以从清空桌面开始，一步步来，60分钟后一定能拥有一个清爽高效的工作空间。</td></tr></table>

# %% [markdown]
# ### Observations
#
# Examine the chain of thought for:
# - Clarity of reasoning
# - Logical progression, or lack thereof
# - How constraints may have affected decision-making
# - Additional insights provided by the reasoning

# %% [markdown]
# ## 5. Reflection & Transfer
#
# Let's reflect on what we've learned from this exercise.

# %% [markdown]
# ### Which prompt tweak changed the output most dramatically and why?
#
# Use this cell to jot down your thoughts: Both the constraints and reasoning prompts changed the output significantly in this case. Both of them had a plan at the beginning. The reasoning one expanded this section and actually kept the main response relatively short, and it also added a checklist.

# %% [markdown]
# ### List two other situations where the same prompt-refinement pattern could help
#
# `TODO: Replace the ***********`
# 1. `***********`
# 2. `***********`

# %% [markdown]
# ## Bonus: Apply what you've learned
#
# Try crafting a prompt for one of your own ideas or even a different organization task (e.g., digital file cleanup, closet overhaul)!

# %%
# Create your own prompts here!

# TODO: Replace the ***********
custom_system_prompt = """
***********
"""
user_prompt = """
***********
"""

# Uncomment the lines below to run your custom prompt
print("Sending custom prompt...")
custom_response = get_completion(custom_system_prompt, user_prompt)
print("Response received!\n")

display_responses(
    {
        "system_prompt": custom_system_prompt,
        "user_prompt": user_prompt,
        "response": custom_response,
    }
)

# %% [markdown]
# ## Summary
#
# In this exercise, we explored how different prompt refinements affect the output of an LLM:
#
# 1. **Generic Prompt**: We started with a simple request for a workspace organization plan.
# 2. **Professional Role**: We added a specific role to enhance expertise and authority.
# 3. **Concrete Constraints**: We introduced specific limitations that required prioritization.
# 4. **Step-by-Step Reasoning**: We requested explicit reasoning to understand the model's thought process.
#
# These techniques demonstrate how prompt engineering can significantly improve the usefulness and relevance of AI-generated content for specific needs.
#
# Excellent Work! 🚀
